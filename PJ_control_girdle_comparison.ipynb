# %% [markdown]
# # Analysis of PJ sites CO2 and H2O flux
#
# First set up environment and load 2009-2014 gapfilled Ameriflux data

# %%
import sys
sys.path.append( '/home/greg/current/NMEG_miscellany/py_modules/' )

# %matplotlib inline
import load_nmeg as ld
import transform_nmeg as tr
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

af_path = '/home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/'

start = 2009
end = 2014

pjc = ld.get_multiyr_aflx( 'US-Mpj', af_path, gapfilled=True, startyear=start, endyear=end )
pjg = ld.get_multiyr_aflx( 'US-Mpg', af_path, gapfilled=True, startyear=start, endyear=end)
jsav = ld.get_multiyr_aflx( 'US-Wjs', af_path, gapfilled=True, startyear=start, endyear=end)

# Substituting old 2009 c flux data in at PJG because there is a big difference that year
# between my files and others. I'm highly suspicious of this move, but it makes sense for now
old_path = '/home/greg/sftp/eddyflux/Ameriflux_files/'
old_pjg_2009 = ld.load_aflx_file( old_path + 'US-Mpg_2009_gapfilled.txt' , 2009 )
pjg.FC[ pjg.index.year == 2009 ] = old_pjg_2009.FC
pjg.GPP[ pjg.index.year == 2009 ] = old_pjg_2009.GPP
pjg.RE[ pjg.index.year == 2009 ] = old_pjg_2009.RE
# Out:
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2009_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2010_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2011_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2012_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2013_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpj_2014_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2009_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2010_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2011_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2012_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2013_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Mpg_2014_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2009_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2010_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2011_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2012_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2013_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/provisional/2007-2014_Reichstein/US-Wjs_2014_gapfilled.txt
# Parsing /home/greg/sftp/eddyflux/Ameriflux_files/US-Mpg_2009_gapfilled.txt

# %% [markdown]
# ## Remove early gapfilling at PJG

# %% [markdown]
# ## Correction for greater NEE at PJG pre-girdling

# %%
girdle_event = dt.datetime( 2009, 9, 5, 12, 0, 0 )
y = pjg.FC[ pjg.index < girdle_event ]
x = pjc.FC[ pjc.index < girdle_event ]
# Remove NaNs
idx = ( ~np.isnan( x + y ))
x = x[ idx ]
y = y[ idx ]
# Get a slope and intercept of the relation between PJG and PJC
A = np.vstack( [ x, np.ones( len( x ) ) ] ).T
slope, icpt =  np.linalg.lstsq( A, y )[0]
print slope, icpt
# Now correct PJC to PJG
pjc_FC_cor = (pjc.FC * slope) + icpt
pjc[ 'FC_cor' ] = pjc_FC_cor
# Out:
# 1.07633878337 -0.33292917073

# %% [markdown]
# ## Calculate ET and create daily data for each site

# %%
pjg_d = tr.resample_aflx( pjg )
pjc_d = tr.resample_aflx( pjc, c_fluxes=[ 'GPP', 'RE', 'FC', 'FC_cor' ] )
jsav_d = tr.resample_aflx( jsav )

pjc_d.YEAR = pjc_d.index.year;
pjg_d.YEAR = pjg_d.index.year;
jsav_d.YEAR = jsav_d.index.year;

# %% [markdown]
# ## Plot timeseries

# %%
fig0 = plt.figure( figsize=( 16.5, 4.5 ), dpi=100, facecolor='w', edgecolor='k' )
ax1 = fig0.add_subplot( 111 )
h1 = ax1.plot( pjc.index, pjc.FC_cor, alpha=.4 ) 
h2 = ax1.plot( pjc.index, pjc.FC )
h3 = ax1.plot( pjg.index, pjg.FC )
plt.ylabel('Fc (umol m-2 s-1)')
plt.legend( [ 'Control corr','Control', 'Girdle'], loc='lower right' )

# %%
fig1 = plt.figure( figsize=( 16.5, 9.5 ), dpi=100, facecolor='w', edgecolor='k' )
ax1 = fig1.add_subplot(211)
h1 = ax1.plot( pjc_d.index, pjc_d.FC_g_int )
h2 = ax1.plot( pjc_d.index, pjc_d.FC_cor_g_int )
h3 = ax1.plot( pjg_d.index, pjg_d.FC_g_int )

plt.ylabel('Fc (gC m-2 d-1)')
plt.legend( ['Control', 'Control corrected', 'Girdle', ], loc='lower right' )
ax2 = fig1.add_subplot(212)
h1 = ax2.plot( pjc_d.index, pjc_d.ET_mm_int_0 ) 
h2 = ax2.plot( pjg_d.index, pjg_d.ET_mm_int_0 )
plt.ylabel('ET (mm m-2)')
plt.show()
#plt.legend( ['Control', 'Girdle'], loc='lower right' )

# %% [markdown]
# ## Compare girdle and control

# %%
def plot_xy_year( yr, ax, var ):
    pjc_sub = pjc_d[ pjc_d.index.year == yr ]
    pjg_sub = pjg_d[ pjg_d.index.year == yr ]
    #jsav_sub = jsav_d[ jsav_d.index.year == yr ]

    ax.scatter( pjc_sub[ var ] , pjg_sub[ var ], marker='o' )
    ax.plot( ( -15, 15 ),( -15, 15 ), ls=':', color='black' )
    plt.ylim([-3, 3])
    plt.xlim([-3, 3])
    plt.text( -2.5, 2.5, str( yr ))

fig2 = plt.figure( figsize=( 12.5, 10.5 ), dpi=100, facecolor='w', edgecolor='k' )
for i, figyr in enumerate( range( start, end + 1 ) ):
    ax1 = fig2.add_subplot( 2, 3, i + 1 )
    plot_xy_year( figyr, ax1, 'FC_g_int' )
    if i==0 or i==3:
        #plt.legend( ['Control', 'Girdle', 'JSav'], loc='upper left' )
        plt.ylabel( 'Girdle')
    elif i==1:
        plt.title(' Cumulative daily NEE' )
    elif i==4:
        plt.xlabel( 'Control')

# %% [markdown]
# ## Plot cumulative NEE

# %%
fig3 = plt.figure( figsize=( 12.5, 6.5 ), dpi=100, facecolor='w', edgecolor='k' )
var = 'FC_g_int'
plt.plot( pjc_d.index, pjc_d[ var ].cumsum())
plt.plot( pjc_d.index, pjc_d[ 'FC_cor_g_int' ].cumsum())
plt.plot( pjg_d.index, pjg_d[ var ].cumsum())
jsav_sub = jsav_d[ jsav_d.index.year < 2014 ]
plt.plot( jsav_sub.index, jsav_sub[ var ].cumsum())
plt.legend( ['Control', 'Control corrected', 'Girdle', 'JSav'], loc='upper right' )

# %%
def plot_cumsum_year( yr, ax, var, annoty=75 ):
    
    pjc_sub = pjc_d[ pjc_d.index.year == yr ]
    pjg_sub = pjg_d[ pjg_d.index.year == yr ]
    jsav_sub = jsav_d[ jsav_d.index.year == yr ]
    
    ax.plot( pjc_sub.index, pjc_sub[ var ].cumsum())
    ax.plot( pjg_sub.index, pjg_sub[ var ].cumsum())
    if yr < 2014 :
        ax.plot( jsav_sub.index, jsav_sub[ var ].cumsum())
    plt.text( dt.datetime( yr, 11, 1 ), annoty, str( yr ))
    # Set major x ticks on Mondays.
    ax.xaxis.set_major_formatter(
    matplotlib.dates.DateFormatter( '%b' ))
    

fig3p5 = plt.figure( figsize=( 14.5, 10.5 ), dpi=100, facecolor='w', edgecolor='k' )
for i, figyr in enumerate( range( start, end + 1 ) ):
    ax1 = fig3p5.add_subplot( 2, 3, i + 1 )
    plot_cumsum_year( figyr, ax1, 'FC_g_int' )
    plt.ylim([ -270, 100])
    if i==0:
        plt.legend( ['Control', 'Girdle', 'JSav'], loc='upper left' )
        plt.ylabel( 'Cumulative NEE ( g )')
    elif i==3:
        plt.ylabel( 'Cumulative NEE ( g )')

# %% [markdown]
# ## Plot cumulative GPP

# %%
fig4 = plt.figure( figsize=( 14.5, 10.5 ), dpi=100, facecolor='w', edgecolor='k' )
for i, figyr in enumerate( range( start, end + 1 ) ):
    ax1 = fig4.add_subplot( 2, 3, i + 1 )
    plot_cumsum_year( figyr, ax1, 'GPP_g_int', annoty=820 )
    plt.ylim([ -10, 900])
    if i==0:
        plt.legend( ['Control', 'Girdle', 'JSav'], loc='upper left' )
        plt.ylabel( 'Cumulative GPP ( g )')
    elif i==3:
        plt.ylabel( 'Cumulative GPP ( g )')

# %% [markdown]
# ## Plot cumulative RE

# %%
fig5 = plt.figure( figsize=( 14.5, 10.5 ), dpi=100, facecolor='w', edgecolor='k' )
for i, figyr in enumerate( range( start, end + 1 ) ):
    ax1 = fig5.add_subplot( 2, 3, i + 1 )
    plot_cumsum_year( figyr, ax1, 'RE_g_int', annoty=550 )
    plt.ylim([ -10, 600])
    if i==0:
        plt.legend( ['Control', 'Girdle', 'JSav'], loc='upper left' )
        plt.ylabel( 'Cumulative RE ( g )')
    elif i==3:
        plt.ylabel( 'Cumulative RE ( g )')
